# %% [markdown]
# # Prabal_Ghosh_Roll-AM.SC.P2CSC20040_Assignment-5_SVM

# %%
import pandas as pd
data = pd.read_csv("C:/Users/Prabal Ghosh/Desktop/iris.csv")

# %% [markdown]
# import pandas as pd
# data = pd.read_csv("D:/semester 3 videos/Machine Learning/labs/iris.csv")

# %%
data.head()
# Out:
#    sepal length  sepal width  petal length  petal width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
len(data)
# Out:
# 150

# %%
# train and test split 
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(data, test_size = 0.2, random_state = 1)

# random_state =1 ......so every time it will generate same train and test set

# %%
len(train_data)
# Out:
# 120

# %%
len(test_data)
# Out:
# 30

# %%
X_train_data_frame= train_data.iloc[:,0:4]
X_train_data_frame
# Out:
#      sepal length  sepal width  petal length  petal width
# 91            6.1          3.0           4.6          1.4
# 135           7.7          3.0           6.1          2.3
# 69            5.6          2.5           3.9          1.1
# 128           6.4          2.8           5.6          2.1
# 114           5.8          2.8           5.1          2.4
# ..            ...          ...           ...          ...
# 133           6.3          2.8           5.1          1.5
# 137           6.4          3.1           5.5          1.8
# 72            6.3          2.5           4.9          1.5
# 140           6.7          3.1           5.6          2.4
# 37            4.9          3.1           1.5          0.1
#
# [120 rows x 4 columns]

# %%
X_train = train_data.iloc[:,0:4].values
Y_train = train_data.iloc[:,4].values


X_test = test_data.iloc[:,0:4].values
Y_test = test_data.iloc[:,4].values

# %%
len(Y_test)
# Out:
# 30

# %% [markdown]
# # Apply Linear SVM (Support Vector Machine)

# %%
from sklearn.svm import SVC
classifier=SVC(kernel="linear")
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
from sklearn.metrics import accuracy_score
Y_pred = classifier.predict(X_test)
accuracy_score(Y_test, Y_pred)
# Out:
# 1.0

# %% [markdown]
# here linear svm classify those datas into different classes with accuracy 100%

# %% [markdown]
# # SVM  (Support Vector Machine)

# %% [markdown]
#   here c=100 ... which is a very high value for C....So it will suffer from overfitting problem

# %%
from sklearn.svm import SVC
classifier = SVC(C=100,random_state=1)  # linear svm applied
classifier.fit(X_train,Y_train)
# Out:
# SVC(C=100, random_state=1)

# %%
print(classifier.support_vectors_)

Y_pred = classifier.predict(X_test)
# Out:
# [[5.1 3.3 1.7 0.5]
#  [4.5 2.3 1.3 0.3]
#  [4.8 3.4 1.9 0.2]
#  [6.  2.7 5.1 1.6]
#  [6.9 3.1 4.9 1.5]
#  [5.9 3.2 4.8 1.8]
#  [4.9 2.4 3.3 1. ]
#  [6.1 2.9 4.7 1.4]
#  [6.2 2.2 4.5 1.5]
#  [6.3 2.5 4.9 1.5]
#  [6.  2.2 5.  1.5]
#  [7.7 3.8 6.7 2.2]
#  [6.2 2.8 4.8 1.8]
#  [6.1 3.  4.9 1.8]
#  [6.  3.  4.8 1.8]
#  [4.9 2.5 4.5 1.7]
#  [6.3 2.8 5.1 1.5]]

# %%
test_data["Predictions"] = Y_pred
# Out:
# <ipython-input-89-3d7df7362ea7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data["Predictions"] = Y_pred

# %%
test_data
# Out:
#      sepal length  sepal width  petal length  petal width          species  \
# 14            5.8          4.0           1.2          0.2      Iris-setosa
# 98            5.1          2.5           3.0          1.1  Iris-versicolor
# 75            6.6          3.0           4.4          1.4  Iris-versicolor
# 16            5.4          3.9           1.3          0.4      Iris-setosa
# 131           7.9          3.8           6.4          2.0   Iris-virginica
# 56            6.3          3.3           4.7          1.6  Iris-versicolor
# 141           6.9          3.1           5.1          2.3   Iris-virginica
# 44            5.1          3.8           1.9          0.4      Iris-setosa
# 29            4.7          3.2           1.6          0.2      Iris-setosa
# 120           6.9          3.2           5.7          2.3   Iris-virginica
# 94            5.6          2.7           4.2          1.3  Iris-versicolor
# ...

# %% [markdown]
# in this above test data  77th data row is wrongly predicted., as its a overfitting problem

# %%
from sklearn.metrics import accuracy_score
Y_pred = classifier.predict(X_test)
accuracy_score(Y_test, Y_pred)
# Out:
# 0.9666666666666667

# %%
from sklearn.metrics import classification_report, confusion_matrix
cm = confusion_matrix(Y_test,Y_pred)
print(cm)
print(classification_report(Y_test, Y_pred))
accuracy = float(cm.diagonal().sum())/len(Y_test)     #   cm.diagonal()=(11+12+6)  and   len(Y_test)=30
print("\nAccuracy Of SVM For IRIS Dataset : ", accuracy)
# Out:
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30
#
#
# Accuracy Of SVM For IRIS Dataset :  0.9666666666666667

# %% [markdown]
# the accuracy is not 1 as we choose high C value ...becuse of that it suffers from overfitting problem

# %% [raw]
# now to eleminite the overfitting problem we choose Lower value  for C=10

# %%
from sklearn.svm import SVC
classifier = SVC(C=10,random_state=1)
classifier.fit(X_train,Y_train)
# Out:
# SVC(C=10, random_state=1)

# %%
print(classifier.support_vectors_)
Y_pred = classifier.predict(X_test)
# Out:
# [[5.1 3.3 1.7 0.5]
#  [4.5 2.3 1.3 0.3]
#  [4.8 3.4 1.9 0.2]
#  [6.5 2.8 4.6 1.5]
#  [6.  3.4 4.5 1.6]
#  [5.7 2.8 4.5 1.3]
#  [6.  2.7 5.1 1.6]
#  [6.9 3.1 4.9 1.5]
#  [5.9 3.2 4.8 1.8]
#  [4.9 2.4 3.3 1. ]
#  [6.1 2.9 4.7 1.4]
#  [6.2 2.2 4.5 1.5]
#  [6.3 2.5 4.9 1.5]
#  [6.  2.2 5.  1.5]
#  [7.7 3.8 6.7 2.2]
#  [6.2 2.8 4.8 1.8]
#  [6.3 2.7 4.9 1.8]
#  [6.1 3.  4.9 1.8]
#  [6.5 3.2 5.1 2. ]
#  [6.  3.  4.8 1.8]
#  [5.9 3.  5.1 1.8]
#  [4.9 2.5 4.5 1.7]
#  [7.2 3.  5.8 1.6]
#  [6.3 2.8 5.1 1.5]]

# %%
from sklearn.metrics import accuracy_score
Y_pred = classifier.predict(X_test)
accuracy_score(Y_test, Y_pred)   # to find the prediction accuracy  of this svc model
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report, confusion_matrix
cm = confusion_matrix(Y_test,Y_pred)
print(cm)
print(classification_report(Y_test, Y_pred))
accuracy = float(cm.diagonal().sum())/len(Y_test)
print("\nAccuracy Of SVM For IRIS Dataset : ", accuracy)
# Out:
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         6
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
#
#
# Accuracy Of SVM For IRIS Dataset :  1.0

# %%
test_data["Predictions"] = Y_pred
# Out:
# <ipython-input-97-3d7df7362ea7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data["Predictions"] = Y_pred

# %%
test_data
# Out:
#      sepal length  sepal width  petal length  petal width          species  \
# 14            5.8          4.0           1.2          0.2      Iris-setosa
# 98            5.1          2.5           3.0          1.1  Iris-versicolor
# 75            6.6          3.0           4.4          1.4  Iris-versicolor
# 16            5.4          3.9           1.3          0.4      Iris-setosa
# 131           7.9          3.8           6.4          2.0   Iris-virginica
# 56            6.3          3.3           4.7          1.6  Iris-versicolor
# 141           6.9          3.1           5.1          2.3   Iris-virginica
# 44            5.1          3.8           1.9          0.4      Iris-setosa
# 29            4.7          3.2           1.6          0.2      Iris-setosa
# 120           6.9          3.2           5.7          2.3   Iris-virginica
# 94            5.6          2.7           4.2          1.3  Iris-versicolor
# ...

# %% [markdown]
# HERE ACCURACY IS 1, SO THE PREDICTION IS CORRECT
