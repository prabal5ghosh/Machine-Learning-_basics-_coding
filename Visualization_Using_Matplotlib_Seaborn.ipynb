# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris_data = pd.read_csv('C:/Users/Rajesh/Desktop/Lab3_24_02/Iris.csv',na_values='NA')
iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_data[0:12].agg(['min','mean','max','median'])
# Out:
#           Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# min      1.0            4.4          2.90       1.300000      0.100000
# mean     6.5            4.9          3.35       1.466667      0.216667
# max     12.0            5.4          3.90       1.700000      0.400000
# median   6.5            4.9          3.40       1.450000      0.200000
#
#             Species
# min     Iris-setosa
# mean            NaN
# max     Iris-setosa
# median          NaN

# %%
iris_data[['SepalLengthCm','SepalWidthCm']].agg(['min','mean','max','median'])
# Out:
#         SepalLengthCm  SepalWidthCm
# min          4.300000         2.000
# mean         5.843333         3.054
# max          7.900000         4.400
# median       5.800000         3.000

# %%
iris_data.mode()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.0           3.0            1.5           0.2
# 1      2            NaN           NaN            NaN           NaN
# 2      3            NaN           NaN            NaN           NaN
# 3      4            NaN           NaN            NaN           NaN
# 4      5            NaN           NaN            NaN           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            NaN           NaN            NaN           NaN
# 146  147            NaN           NaN            NaN           NaN
# 147  148            NaN           NaN            NaN           NaN
# 148  149            NaN           NaN            NaN           NaN
# 149  150            NaN           NaN            NaN           NaN
#
#              Species
# 0        Iris-setosa
# 1    Iris-versicolor
# 2     Iris-virginica
# 3                NaN
# 4                NaN
# ..               ...
# ...

# %%
iris_data.skew()
# Out:
# Id               0.000000
# SepalLengthCm    0.314911
# SepalWidthCm     0.334053
# PetalLengthCm   -0.274464
# PetalWidthCm    -0.104997
# dtype: float64

# %%
#seaborn example scatter plot
sns.relplot(x='SepalLengthCm',y='SepalWidthCm',hue = "Species",size="Species",data=iris_data)

# %%
#seaborn example scatter plot and histogram
sns.pairplot(iris_data.dropna())

# %%
#seaborn example scatter plot and histogram
sns.pairplot(iris_data)

# %%
#Matplotlib,Pandas example histogram

iris_data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Id'}>,
#         <AxesSubplot:title={'center':'SepalLengthCm'}>],
#        [<AxesSubplot:title={'center':'SepalWidthCm'}>,
#         <AxesSubplot:title={'center':'PetalLengthCm'}>],
#        [<AxesSubplot:title={'center':'PetalWidthCm'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
#Matplotlib and Pandas example Kernel Density Estimate

iris_data.PetalWidthCm.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#Pandas and Matplotlib example scatter_Matrix

from pandas.plotting import scatter_matrix
scatter_matrix(iris_data[['SepalLengthCm','PetalLengthCm']])
plt.show()

# %%
#Matplotlib example histogram

plt.hist(iris_data.PetalLengthCm, bins=10, edgecolor='black')
plt.show()

# %%
#Matplotlib example scatter

plt.scatter(iris_data.PetalLengthCm,iris_data.PetalWidthCm)
plt.xlabel("petal_length")
plt.ylabel("petal_width")
plt.show()

# %%
#seaborn example box plot

sns.boxplot(x='PetalLengthCm', data=iris_data)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm'>

# %%
#seaborn example box plot

sns.boxplot(x='PetalWidthCm', data=iris_data)
# Out:
# <AxesSubplot:xlabel='PetalWidthCm'>

# %%
#seaborn example box plot

sns.boxplot(x='SepalLengthCm', data=iris_data)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm'>

# %%
#seaborn example box plot

sns.boxplot(x='SepalWidthCm', data=iris_data)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm'>

# %%
#seaborn example box plot

sns.boxplot(x='Species', y='PetalWidthCm', data=iris_data)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %%
df= pd.read_csv('C:/Users/Rajesh/Desktop/Lab3_24_02/CancerWisconsin_data.csv',na_values='NA')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['diagnosis'].value_counts(dropna = False)
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
#seaborn example box plot

sns.boxplot(x='diagnosis', y='area_mean', data=df)
plt.savefig('seaborn_basic_area_mean_diagnosis.png')

# %%
#Matplotlib and pandas example box plot

df.boxplot(column = 'area_mean', by = 'diagnosis');
plt.title('')
plt.savefig('pandas_basic_area_mean_diagnosis.png')

# %%
#MAtplotlib and Pandas example box plot

iris_data.boxplot(column = 'PetalWidthCm', by = 'Species');
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
df1 = pd.read_csv('C:/Users/Rajesh/Desktop/Lab3_24_02/Salaries.csv',na_values='NA')
df1.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
#seaborn example catplot

sns.catplot(x="rank", y="salary", jitter=False,data=df1)

# %%
#seaborn example hueplot

sns.catplot(x="rank", y="salary", hue="sex",jitter=False,data=df1)

# %%
#seaborn example pointplot

sns.catplot(x="rank", y="salary", hue="sex",jitter=False,kind="point",data=df1)

# %%
#Do the same plots using loan_status data set, employees, CancerWisconsin, upvotes and submit ur 
#jupyter notebook file by today evening.
