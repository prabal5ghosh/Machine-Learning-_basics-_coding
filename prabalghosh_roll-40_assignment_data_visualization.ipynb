# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Auto1_data = pd.read_csv("E:/class lectures/data mining/lab/Lab3_24_02/Auto1.csv",na_values='NA')

# %%
Auto1_data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
Auto1_data[0:12].agg(['min','mean','max','median'])
# Out:
#               mpg  cylinders  displacement   horsepower   weight  \
# min     14.000000        8.0    302.000000          130  3433.00
# mean    15.416667        8.0    372.666667  1.08471e+34  3830.75
# max     18.000000        8.0    455.000000          225  4425.00
# median  15.000000        8.0    366.500000        167.5  3651.00
#
#         acceleration  year  origin
# min         8.000000  70.0     1.0
# mean       10.083333  70.0     1.0
# max        12.000000  70.0     1.0
# median     10.000000  70.0     1.0

# %%
Auto1_data[['cylinders','displacement']].agg(['min','mean','max','median'])
# Out:
#         cylinders  displacement
# min      3.000000     68.000000
# mean     5.458438    193.532746
# max      8.000000    455.000000
# median   4.000000    146.000000

# %%
Auto1_data.mode()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  13.0        4.0          97.0        150    1985          14.5  73.0
# 1   NaN        NaN           NaN        NaN    2130           NaN   NaN
#
#    origin
# 0     1.0
# 1     NaN

# %%
Auto1_data.skew()
# Out:
# mpg             0.456005
# cylinders       0.522818
# displacement    0.716282
# weight          0.530989
# acceleration    0.280818
# year            0.013108
# origin          0.919911
# dtype: float64

# %%
#seaborn example scatter plot
sns.relplot(x='cylinders',y='displacement',hue = "origin",size="weight",data=Auto1_data)

# %%
#seaborn example scatter plot and histogram
sns.pairplot(Auto1_data.dropna())

# %%
#seaborn example scatter plot and histogram
sns.pairplot(Auto1_data)

# %%
Auto1_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A4A244F1F0>,
# ...
#       dtype=object)

# %%
Auto1_data.cylinders.plot(kind='kde')

# %%
#Pandas and Matplotlib example scatter_Matrix

from pandas.plotting import scatter_matrix
scatter_matrix(Auto1_data[['cylinders','displacement']])
plt.show()

# %%
#Matplotlib example histogram

plt.hist(Auto1_data.cylinders, bins=10, edgecolor='black')
plt.show()

# %%
#Matplotlib example scatter

plt.scatter(Auto1_data.cylinders,Auto1_data.displacement)
plt.xlabel("cylinders")
plt.ylabel("displacement")
plt.show()

# %%
#seaborn example box plot

sns.boxplot(x='displacement', data=Auto1_data)

# %%
#seaborn example box plot

sns.boxplot(x='cylinders', data=Auto1_data)

# %%
#seaborn example box plot

sns.boxplot(x='weight', data=Auto1_data)

# %%
#seaborn example box plot

sns.boxplot(x='acceleration', data=Auto1_data)

# %%
#seaborn example box plot

sns.boxplot(x='origin', data=Auto1_data)

# %%
#seaborn example box plot

sns.boxplot(x='year', data=Auto1_data)

# %%
#seaborn example box plot

sns.boxplot(x='mpg', data=Auto1_data)

# %%
#seaborn example box plot

sns.boxplot(x='cylinders', y='displacement', data=Auto1_data)

# %%
#seaborn example box plot

sns.boxplot(x='origin', y='displacement', data=Auto1_data)

# %%
df= pd.read_csv('E:\class lectures\data mining\lab\Lab3_24_02/CancerWisconsin_data.csv',na_values='NA')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['diagnosis'].value_counts(dropna = False)
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
#seaborn example box plot

sns.boxplot(x='diagnosis', y='area_mean', data=df)
plt.savefig('seaborn_basic_area_mean_diagnosis.png')

# %%
#Matplotlib and pandas example box plot

df.boxplot(column = 'area_mean', by = 'diagnosis');
plt.title('')
plt.savefig('pandas_basic_area_mean_diagnosis.png')

# %%
#MAtplotlib and Pandas example box plot

Auto1_data.boxplot(column = 'displacement', by = 'origin');
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
df1 = pd.read_csv('E:\class lectures\data mining\lab\Lab3_24_02/Salaries.csv',na_values='NA')
df1.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
#seaborn example catplot

sns.catplot(x="rank", y="salary", jitter=False,data=df1)

# %%
#seaborn example hueplot

sns.catplot(x="rank", y="salary", hue="sex",jitter=False,data=df1)

# %%
#seaborn example pointplot

sns.catplot(x="rank", y="salary", hue="sex",jitter=False,kind="point",data=df1)
