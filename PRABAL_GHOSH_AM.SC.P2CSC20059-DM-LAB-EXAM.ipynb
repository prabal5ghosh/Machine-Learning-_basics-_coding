# %% [markdown]
# # ROLL NO:AM.SC.P2CSC21027 NAME:BODHISATTWA BAIDYA

# %% [markdown]
# # LAB EXAM SET 2

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # Read it to a dataframe.

# %%
colnames = ["balance","left_weight","left_distance","right_weight","right_distance"];
dataframe_1 = pd.read_csv('C:/Users/Prabal Ghosh/Desktop/balance-scale.data', names=colnames, header=None, na_values='NA')

# %%
dataframe_1.head()
# Out:
#   balance  left_weight  left_distance  right_weight  right_distance
# 0       B            1              1             1               1
# 1       R            1              1             1               2
# 2       R            1              1             1               3
# 3       R            1              1             1               4
# 4       R            1              1             1               5

# %% [markdown]
# #  visualization functions and give the descriptive statistics of numerical columns.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import VotingClassifier
import seaborn as sns
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1. pairplot

# %%
sns.pairplot(dataframe_1)

# %%
sns.pairplot(dataframe_1, hue='balance')

# %%
sns.pairplot(dataframe_1, hue='balance',kind='reg')

# %% [markdown]
# 2. JOINT PLOT

# %%
#PRABAL GHOSH
sns.jointplot(x ='right_weight', y ='right_distance', data = dataframe_1)

# %% [markdown]
# 3. Count plot

# %%
ax = sns.countplot(x="balance", data=dataframe_1)

# %%
ax = sns.countplot(x="balance", hue="right_distance", data=dataframe_1)

# %% [markdown]
# 4.  Scatter plot

# %%
plt.scatter(dataframe_1.balance,dataframe_1.right_distance)
plt.xlabel("balance")
plt.ylabel("right_distance")
# Out:
# Text(0, 0.5, 'right_distance')

# %% [markdown]
# 5. Histogram plot

# %%
dataframe_1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FD6E2C3F70>,
# ...
#       dtype=object)

# %% [markdown]
# # Preprocess the data if required by removing null values (if any).

# %% [markdown]
# PRABAL GHOSH

# %%
dataframe_1.dropna()
# Out:
#     balance  left_weight  left_distance  right_weight  right_distance
# 0         B            1              1             1               1
# 1         R            1              1             1               2
# 2         R            1              1             1               3
# 3         R            1              1             1               4
# 4         R            1              1             1               5
# ..      ...          ...            ...           ...             ...
# 620       L            5              5             5               1
# 621       L            5              5             5               2
# 622       L            5              5             5               3
# 623       L            5              5             5               4
# 624       B            5              5             5               5
#
# [625 rows x 5 columns]

# %%
dataframe_1.dropna(axis=0,how='any',inplace=True) # implace is used for parmenent effect on the dataframe
dataframe_1
# Out:
#     balance  left_weight  left_distance  right_weight  right_distance
# 0         B            1              1             1               1
# 1         R            1              1             1               2
# 2         R            1              1             1               3
# 3         R            1              1             1               4
# 4         R            1              1             1               5
# ..      ...          ...            ...           ...             ...
# 620       L            5              5             5               1
# 621       L            5              5             5               2
# 622       L            5              5             5               3
# 623       L            5              5             5               4
# 624       B            5              5             5               5
#
# [625 rows x 5 columns]

# %%
#data has no null values

# %% [markdown]
# # g. Split the data into training set and test set.

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score

# %%
X = dataframe_1.drop('balance',axis=1)
Y = dataframe_1['balance']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

# %%
len(X_train)
# Out:
# 437

# %%
len(X_test)
# Out:
# 188

# %%
X_test
# Out:
#      left_weight  left_distance  right_weight  right_distance
# 419            4              2             4               5
# 73             1              3             5               4
# 209            2              4             2               5
# 259            3              1             2               5
# 469            4              4             4               5
# ..           ...            ...           ...             ...
# 428            4              3             1               4
# 296            3              2             5               2
# 318            3              3             4               4
# 603            5              5             1               4
# 471            4              4             5               2
#
# [188 rows x 4 columns]

# %%
X_train
# Out:
#      left_weight  left_distance  right_weight  right_distance
# 593            5              4             4               4
# 361            3              5             3               2
# 605            5              5             2               1
# 171            2              2             5               2
# 44             1              2             4               5
# ..           ...            ...           ...             ...
# 450            4              4             1               1
# 172            2              2             5               3
# 525            5              2             1               1
# 438            4              3             3               4
# 223            2              4             5               4
#
# [437 rows x 4 columns]

# %%
y_test
# Out:
# 419    R
# 73     R
# 209    R
# 259    R
# 469    R
#       ..
# 428    L
# 296    R
# 318    R
# 603    L
# 471    L
# Name: balance, Length: 188, dtype: object

# %%
y_train
# Out:
# 593    L
# 361    L
# 605    L
# 171    R
# 44     R
#       ..
# 450    L
# 172    R
# 525    L
# 438    B
# 223    R
# Name: balance, Length: 437, dtype: object

# %% [markdown]
# # Apply Decision Tree Classifier on the data. Calculate the accuracy and classification report

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7553191489361702

# %%
#import classification_report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.00      0.00      0.00        10
#            L       0.83      0.83      0.83        78
#            R       0.92      0.77      0.84       100
#
#     accuracy                           0.76       188
#    macro avg       0.58      0.53      0.56       188
# weighted avg       0.83      0.76      0.79       188

# %% [markdown]
# # h. Apply Ensemble model on the data. Calculate the accuracy and classification report.

# %%
#importing important packages
# PRABAL GHOSH
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.ensemble import RandomForestClassifier
#Import scikit-learn metrics module for accuracy calculation
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# METHOD-1

# %%
model1 = tree.DecisionTreeClassifier()
model2 = KNeighborsClassifier()

model1.fit(X_train,y_train)
model2.fit(X_train,y_train)

print("DT (Model 1) Score: ", model1.score(X_test,y_test))
print("kNN (Model 2) Score: ", model2.score(X_test,y_test))

pred1=model1.predict(X_test)
pred2=model2.predict(X_test)

#Analyze the output produced above by printing out the pred1, pred2 and pred3
#Max Voting using Mode function
# PRABAL GHOSH

print(pred1)
print(pred2)
# Out:
# DT (Model 1) Score:  0.7606382978723404
# kNN (Model 2) Score:  0.8404255319148937
# ['R' 'R' 'R' 'R' 'R' 'L' 'B' 'L' 'L' 'R' 'R' 'L' 'R' 'R' 'B' 'L' 'R' 'L'
#  'R' 'L' 'L' 'R' 'L' 'R' 'L' 'L' 'R' 'R' 'L' 'B' 'L' 'R' 'R' 'L' 'L' 'B'
#  'R' 'R' 'R' 'R' 'R' 'B' 'R' 'L' 'L' 'R' 'L' 'L' 'R' 'L' 'R' 'B' 'L' 'B'
#  'L' 'L' 'L' 'L' 'R' 'R' 'R' 'R' 'B' 'B' 'R' 'L' 'L' 'B' 'R' 'L' 'R' 'L'
#  'L' 'B' 'L' 'R' 'R' 'R' 'R' 'R' 'L' 'L' 'R' 'L' 'L' 'B' 'L' 'L' 'L' 'B'
#  'B' 'L' 'R' 'R' 'R' 'B' 'L' 'L' 'R' 'L' 'B' 'L' 'R' 'L' 'R' 'L' 'L' 'L'
#  'R' 'R' 'R' 'L' 'R' 'B' 'L' 'L' 'R' 'R' 'R' 'R' 'B' 'R' 'R' 'L' 'R' 'R'
#  'R' 'L' 'L' 'R' 'R' 'L' 'B' 'L' 'L' 'R' 'L' 'R' 'R' 'L' 'B' 'R' 'B' 'L'
#  'L' 'R' 'R' 'R' 'L' 'R' 'R' 'R' 'B' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L'
#  'R' 'L' 'R' 'L' 'R' 'R' 'B' 'R' 'B' 'R' 'L' 'R' 'L' 'R' 'R' 'R' 'R' 'B'
#  'L' 'L' 'L' 'L' 'B' 'R' 'L' 'L']
# ['R' 'R' 'R' 'R' 'B' 'R' 'B' 'L' 'L' 'R' 'R' 'L' 'B' 'R' 'B' 'R' 'R' 'L'
# ...

# %%
#Create a Decision Tree Classifier
model1 = tree.DecisionTreeClassifier()
#Train the model using the training sets
model1.fit(X_train,y_train)
#Predict y values using the fitted model on test set
y_pred1 = model1.predict(X_test)
# Decision Tree Accuracy by comparing actual and predicted values of y
print("Accuracy:",metrics.accuracy_score(y_test, y_pred1))
# model1.predict([[3, 5, 40, 2]])
# Out:
# Accuracy: 0.7553191489361702

# %%
#import classification_report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.00      0.00      0.00        10
#            L       0.83      0.83      0.83        78
#            R       0.92      0.77      0.84       100
#
#     accuracy                           0.76       188
#    macro avg       0.58      0.53      0.56       188
# weighted avg       0.83      0.76      0.79       188

# %% [markdown]
# METHOD-2

# %%
#Create a Decision Tree Classifier
model1 = tree.DecisionTreeClassifier()
#Train the model using the training sets
model1.fit(X_train,y_train)
#Predict y values using the fitted model on test set
y_pred1 = model1.predict(X_test)
# Decision Tree Accuracy by comparing actual and predicted values of y
print("Accuracy:",metrics.accuracy_score(y_test, y_pred1))
model1.predict([[3, 5, 4, 2]])
# Out:
# Accuracy: 0.7446808510638298
# array(['L'], dtype=object)

# %%
#Create a Random Forest Classifier
model2=RandomForestClassifier(n_estimators=50)
#Train the model using the training
model2.fit(X_train,y_train)
#Predict y values using the fitted model
y_pred2=model2.predict(X_test)
# Random Forest Model Accuracy by comparing actual and predicted values of y
print("Accuracy:", metrics.accuracy_score(y_test, y_pred2))
#model2.predict([[3, 5, 4, 2]])
# Out:
# Accuracy: 0.8404255319148937

# %%
#import classification_report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.00      0.00      0.00        10
#            L       0.82      0.82      0.82        78
#            R       0.93      0.76      0.84       100
#
#     accuracy                           0.74       188
#    macro avg       0.58      0.53      0.55       188
# weighted avg       0.83      0.74      0.78       188

# %%
#import classification_report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.00      0.00      0.00        10
#            L       0.88      0.90      0.89        78
#            R       0.93      0.88      0.90       100
#
#     accuracy                           0.84       188
#    macro avg       0.60      0.59      0.60       188
# weighted avg       0.86      0.84      0.85       188

# %%
# ENSEMBLE MODEL CRETION AND ACCURACY

# %%
model1s_new = tree.DecisionTreeClassifier(random_state=1)
model2s_new = RandomForestClassifier()

modelfs_new = VotingClassifier(estimators=[('dt', model1s_new), ('rf', model2s_new)], voting='hard')
modelfs_new.fit(X_train,y_train)
modelfs_new.score(X_test,y_test)
# Out:
# 0.7712765957446809

# %%
y_pred = modelfs_new.predict(X_test)
print(y_pred)
print(y_test)
# Out:
# ['R' 'R' 'R' 'R' 'R' 'L' 'B' 'L' 'L' 'R' 'R' 'L' 'R' 'R' 'B' 'L' 'R' 'L'
#  'R' 'L' 'L' 'R' 'L' 'R' 'L' 'L' 'R' 'R' 'L' 'B' 'L' 'R' 'R' 'L' 'L' 'B'
#  'R' 'R' 'L' 'R' 'R' 'L' 'R' 'L' 'L' 'R' 'L' 'B' 'R' 'L' 'R' 'B' 'L' 'B'
#  'L' 'L' 'L' 'L' 'R' 'R' 'R' 'R' 'B' 'B' 'R' 'L' 'L' 'B' 'R' 'L' 'R' 'L'
#  'L' 'B' 'L' 'R' 'R' 'R' 'R' 'R' 'L' 'L' 'R' 'L' 'L' 'B' 'L' 'L' 'L' 'B'
#  'B' 'L' 'R' 'R' 'R' 'B' 'L' 'L' 'R' 'L' 'B' 'L' 'R' 'L' 'R' 'L' 'L' 'L'
#  'R' 'R' 'R' 'L' 'R' 'B' 'L' 'L' 'R' 'R' 'R' 'R' 'B' 'R' 'R' 'L' 'R' 'R'
#  'B' 'L' 'L' 'R' 'L' 'L' 'B' 'L' 'L' 'R' 'L' 'R' 'R' 'L' 'B' 'R' 'B' 'L'
#  'L' 'R' 'R' 'R' 'L' 'R' 'R' 'R' 'B' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L'
#  'R' 'L' 'R' 'L' 'R' 'R' 'B' 'R' 'B' 'R' 'L' 'R' 'L' 'R' 'R' 'R' 'R' 'B'
#  'L' 'L' 'L' 'L' 'B' 'R' 'L' 'L']
# 419    R
# 73     R
# 209    R
# 259    R
# 469    R
#       ..
# 428    L
# 296    R
# 318    R
# 603    L
# 471    L
# Name: balance, Length: 188, dtype: object

# %% [markdown]
# # i. Find outliers(if any) in the numerical columns of the original data using box plot and remove them from the data. Retrain your models on cleansed data and compare the results.

# %%
#PRABAL GHOSH
sns.boxplot(x='left_distance', data=dataframe_1)

# %%
sns.boxplot(x='right_distance', data=dataframe_1)

# %%
sns.boxplot(x='left_weight', data=dataframe_1)

# %%
sns.boxplot(x='right_weight', data=dataframe_1)

# %% [markdown]
#  No outliers, all data is evenly and perfectly spaced, no need to trim and retrain data

# %% [markdown]
# # j. Apply PCA on the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import VotingClassifier # PRABAL GHOSH

# %%
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
PCA.fit(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-96109a7317ce> in <module>
# ----> 1 PCA.fit(X)
#
# TypeError: fit() missing 1 required positional argument: 'X'

# %%
x=StandardScaler().fit_transform(X)
print(x.shape)

# %%
x_pca=PCA(n_components=2) # CONVERT THE 4 DOMENSION INTO 2 DIMENSION 
x_pca.fit(x)

# %%
print(x_pca.components_)
