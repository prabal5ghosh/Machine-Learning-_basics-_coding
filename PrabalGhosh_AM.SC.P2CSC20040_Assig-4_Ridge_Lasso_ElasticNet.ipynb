# %% [markdown]
# # Prabal Ghosh Roll-AM.SC.P2CSC20040 Assignment-4 (Machine learning)-Ridge_Lasso_ElasticNet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("D:\\semester 3 videos\\Machine Learning\\notes\\Lab\\Lab4_06_09_Regularization\\advertising.csv")
print(data.head())
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
print(data.head())
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=data, x="TV", y="sales")
plt.grid(True)

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=data, x="radio", y="sales")
plt.grid(True)

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=data, x="newspaper", y="sales")
plt.grid(True)

# %%
def scatter_plot(feature, target):
    plt.figure(figsize=(10, 8))
    plt.scatter(data[feature],
                data[target],
                c='black'
                )
    plt.xlabel("Money Spent on {} ads ($)".format(feature))
    plt.ylabel("Sales ($k)")
    plt.show()
scatter_plot("TV", "sales")
scatter_plot("radio", "sales")
scatter_plot("newspaper", "sales")

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

xs = data.drop(["sales"], axis=1)
y = data["sales"].values.reshape(-1,1)
linreg = LinearRegression()
linreg.fit(xs,y)
# Out:
# LinearRegression()

# %%
print(linreg.coef_)
# Out:
# [[ 0.04576465  0.18853002 -0.00103749]]

# %%
from sklearn.linear_model import Ridge, RidgeCV,Lasso,LassoCV,ElasticNet


xs = data.drop(["sales"], axis=1)
y = data["sales"].values.reshape(-1,1)
Rreg = Ridge(alpha=.1, normalize=True)
Rreg.fit(xs,y)
print(Rreg.coef_)
# Out:
# [[0.04169741 0.17023221 0.00389802]]

# %%
xs = data.drop(["sales"], axis=1)
y = data["sales"].values.reshape(-1,1)
Lreg = Lasso(alpha=.1, normalize=True)
Lreg.fit(xs,y)
print(Lreg.coef_)
# Out:
# [0.03009928 0.09746336 0.        ]

# %%
xs = data.drop(["sales"], axis=1)
y = data["sales"].values.reshape(-1,1)
enet = ElasticNet(alpha=.1, normalize=True)
enet.fit(xs,y)
print(enet.coef_)
# Out:
# [0.00355679 0.01388839 0.00163607]
